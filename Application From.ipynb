# %%
from tkinter import *
from tkinter import messagebox as tmsg
root=Tk()
root.title('Application From')
root.resizable(False, False)
#root.geometry("1600x900")
root.configure(bg='Grey')

def selected_item():
    for i in label2.curselection():
        print(label2.get(i))
def selected_item1():
    for i in label2.curselection():
        print(label2.get(i))
def selected_item2():
    for i in label3.curselection():
        print(label3.get(i))
def printinfo():
    print(f"{entry1.get(),entry2.get(),entry3.get(),entry4.get(),entry5.get()}")
    
    with open("Student_List.txt","a") as sd:
        sd.write(f"name is {entry1.get(),entry2.get(),entry3.get(),entry4.get(),entry5.get()}\n")
    submit=tmsg.askquestion("Confirm", "Are you sure you want to submit?")
    if submit=='yes':
        msg='Application Submitted.'
    else: msg='Please make necessary changes.'
    tmsg.showinfo('Submit',msg)
    Button(f1,text='Logout',font="Helvtica 12 bold",bg='SeaGreen1',command=root.destroy,activeforeground='green3',padx=4,pady=1).grid(row=22,column=2)
    
def deselect():
    cb1.deselect()
    cb2.deselect()
    cb3.deselect()
    cb4.deselect()
    cb5.deselect()
    cb6.deselect()
    cb7.deselect()
    cb8.deselect()
Label(root,text='JOB APPLICATION',relief=GROOVE,font='helvtica 28 bold',bg='navajo white').grid()
    
f1=Frame(root)
f1.grid()
f1.configure(bg='Grey')


label1value=StringVar()
labe11=Label(f1,text="NAME ",font='helvtica 12 bold',bg='white')
labe11.grid(row=1,column=0,sticky='w')

entry1=Entry(f1,textvariable=label1value,justify=CENTER,width=30)
entry1.grid(row=1,column=1)

label1value=StringVar()
label1=Label(f1,text="DATE OF BIRTH (DOB) ",font='helvtica 12 bold',bg='Brown')
label1.grid(row=2,column=0,sticky='w')


label1 = Listbox(f1,bd='3',relief='groove')
label1.grid(row=2,column=1)
label1.insert(1, 'January')
label1.insert(2, 'February')
label1.insert(3, 'March')
label1.insert(4, 'April')
label1.insert(5, 'May')
label1.insert(6, 'June')
label1.insert(7, 'July')
label1.insert(8, 'August')
label1.insert(9, 'September')
label1.insert(10, 'October')
label1.insert(11, 'November')
label1.insert(12, 'December')
scroll_bar=Scrollbar(f1)
scroll_bar.grid(row=2,column=2,sticky=NS)
scroll_bar.config(command=label1.yview)
label1.config(yscrollcommand=scroll_bar.set)
Button(f1,text='Month',bg='Cyan',padx=38,font="Helvtica 10 bold",command=selected_item).grid(row=4,column=1)

label2value=StringVar()
label2=Listbox(f1,bd='3',relief='groove')
label2.grid(row=2,column=3)
for i in range(1,32):
    label2.insert(i,i)
scroll_bar1=Scrollbar(f1)
scroll_bar1.grid(row=2,column=4,sticky=NS)
scroll_bar1.config(command=label2.yview)
label2.config(yscrollcommand=scroll_bar1.set)
Button(f1,text='Date',bg='navajo white',padx=42,font="Helvtica 10 bold",command=selected_item1).grid(row=4,column=3)

label3value=StringVar()
label3=Listbox(f1,bd='3',relief='groove')
label3.grid(row=2,column=5)
for i in range(2023,1962,-1):
    label3.insert(i,i)
scroll_bar12=Scrollbar(f1)
scroll_bar12.grid(row=2,column=6,sticky=NS)
scroll_bar12.config(command=label3.yview)
label3.config(yscrollcommand=scroll_bar12.set)
Button(f1,text='Year',bg='navajo white',padx=42,font="Helvtica 10 bold",command=selected_item2).grid(row=4,column=5)

label4value=StringVar()
label4=Label(f1,text="PRESENT ADDRESS ",bg='Tan',font='helvtica 12 bold')
label4.grid(row=5,column=0,sticky='w')
entry2=Entry(f1,textvariable=label4,justify=CENTER,width=30)
entry2.grid(row=5,column=1)

label5value=StringVar()
label5=Label(f1,text="PHONE NO ",bg='navajo white',font='helvtica 12 bold')
label5.grid(row=7,column=0,sticky='w')
entry3=Entry(f1,textvariable=label5,justify=CENTER,width=30)
entry3.grid(row=7,column=1)

label6value=StringVar()
label6=Label(f1,text="PERSONAL INFORMATION",relief='groove',bg='navajo white',font='helvtica 20 bold')
label6.grid(row=0,column=0)

label7value=StringVar()
label7=Label(f1,text="WRITE YOUR DESCRIPTION",bg='navajo white',font='helvtica 12 bold')
label7.grid(row=9,column=0,sticky='w')
text=Text(f1,height=3,width=40)
text.grid(row=9,column=1)

label8value=StringVar()
label8=Label(f1,text="EMPLOYMENT DESIRED",relief='groove',bg='navajo white',font='helvtica 20 bold')
label8.grid(row=10,column=0)

label9value=StringVar()
label9=Label(f1,text="POSITION",bg='navajo white',font='helvtica 12 bold')
label9.grid(row=11,column=0,sticky='w')
entry4=Entry(f1,textvariable=label8,justify=CENTER,width=30)
entry4.grid(row=11,column=1)

label10value=StringVar()
label10=Label(f1,text="ARE YOU EMPLOYED NOW ",bg='navajo white',font='helvtica 12 bold')
label10.grid(row=12,column=0,sticky='w')

label11value=StringVar()
label11=Label(f1,text="EVER APPLIED TO THIS COMPANY BEFORE",bg='navajo white',font='helvtica 12 bold')
label11.grid(row=13,column=0,sticky='w')

label12value=StringVar()
label12=Label(f1,text="REFERRED BY",bg='navajo white',font='helvtica 12 bold')
label12.grid(row=14,column=0,sticky='w')
entry5=Entry(f1,textvariable=label10,justify=CENTER,width=30)
entry5.grid(row=14,column=1)

label13value=StringVar()
label13=Label(f1,text="JOB TYPE",relief='groove',bg='navajo white',font='helvtica 20 bold')
label13.grid(row=15,column=0)
label13=Label(f1,text="DAYS /HOURS AVAILABLE TO WORK",bg='navajo white',font='helvtica 12 bold')
label13.grid(row=16,column=0,sticky='w')
checkbutton1=Checkbutton(f1,text='I have no prefrence',bg='navajo white',height=1,width=16)
checkbutton1.grid(row=16,column=1)
checkbutton2=Checkbutton(f1,text='Monday',bg='navajo white',height=1,width=16)
checkbutton2.grid(row=16,column=2)
checkbutton3=Checkbutton(f1,text='Thursday',bg='navajo white',height=1,width=16)
checkbutton3.grid(row=16,column=3)
checkbutton4=Checkbutton(f1,text='Saturday',bg='navajo white',height=1,width=16)
checkbutton4.grid(row=17,column=1)
checkbutton5=Checkbutton(f1,text='Tuesday',bg='navajo white',height=1,width=16)
checkbutton5.grid(row=17,column=2)
checkbutton6=Checkbutton(f1,text='Friday',bg='navajo white',height=1,width=16)
checkbutton6.grid(row=17,column=3)
checkbutton7=Checkbutton(f1,text='Sunday',bg='navajo white',height=1,width=16)
checkbutton7.grid(row=18,column=1)
checkbutton8=Checkbutton(f1,text='Wednesday',bg='navajo white',height=1,width=16)
checkbutton8.grid(row=18,column=2)
Button(f1,text='Clear Selection',bg='navajo white',relief='raised',bd='1',command=deselect).grid(row=20,column=2)
label13=Label(f1,text="I AM SEEKING A:",bg='navajo white',font='helvtica 12 bold')
label13.grid(row=21,column=0,sticky='w')

label14=Label(f1,text='''I certify that the facts set forth in this Application for Employment are true 
and complete to the best of my knowledge. I understand that if I am employed, false statements, omissions or misrepresentations 
may result in my dismissal. Therefore, any employee (regular, temporary, or other type of category employee) may resign 
at any time, just as the employer may terminate the employment relationship with any employee at any time, 
with or without cause, with or without notice to the other party.''',font='helvtica 8 bold',bg='navajo white')
label14.grid(row=22,column=0)
checkbutton9=Checkbutton(f1,text='I agree to the terms and conditions',width=28,font='helvtica 8 bold',bg='navajo white')
checkbutton9.grid(row=22,column=1)

Radiobutton1value=IntVar()
Radiobutton1=Radiobutton(f1,text="Yes",bg='navajo white',variable=Radiobutton1value,value=1)
Radiobutton1.grid(row=12,column=1)

Radiobutton2value=IntVar()
Radiobutton2=Radiobutton(f1,text="No",bg='navajo white',variable=Radiobutton1value,value=2)
Radiobutton2.grid(row=12,column=2)

Radiobutton3value=IntVar()
Radiobutton3=Radiobutton(f1,text="Yes",bg='navajo white',variable=Radiobutton3value,value=1)
Radiobutton3.grid(row=13,column=1)

Radiobutton4value=IntVar()
Radiobutton4=Radiobutton(f1,text="No",bg='navajo white',variable=Radiobutton4value,value=2)
Radiobutton4.grid(row=13,column=2)

Radiobutton(f1,text='Full-time job',bg='navajo white',variable=Radiobutton4value,value=1).grid(row=21,column=1)
Radiobutton(f1,text='Part-time job',bg='navajo white',variable=Radiobutton4value,value=2).grid(row=21,column=2)
Radiobutton(f1,text='Full-or Part-time',bg='navajo white',variable=Radiobutton4value,value=3).grid(row=21,column=3)

button=Button(f1,text='SUBMIT',font="Helvtica 12 bold",bg='SeaGreen1',command=printinfo,activeforeground='red')
button.grid(row=22,column=2)

root.mainloop()
